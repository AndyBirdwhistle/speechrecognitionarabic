# %%
import os

ret = os.system("HLEd -l '*' -d dict -i phones0.mlf mkphones0.led  words.mlf")
print(ret)
# Out:
# 0

# %%
words = open("words.mlf", "r")
dictionary = open("dict", "r")
words_list = words.readlines()
dictionary_list = dictionary.readlines()
dictionary_list_copy = [i for i in dictionary_list]

for i in dictionary_list_copy:
    try:
        words_list.remove(i[:i.find("\t")]+"\n")
        print("yes")
    except Exception:
        pass
        print(i[:i.find("\t")])

#words_list
# Out:
# ONETHREE
# TWOZEROZEROFIVE
# TWOZEROONEFOUR
# TWOZEROONEFIVE
# SIXSIX
# آبَاؤُهُم
# آلِ
# آمل
# أتعلَّمَ
# أتعلّم
# أَجْلِ
# أُحَاوِلُ
# أحْلاَمَهَا
# أحْيَتِ
# أَدِلَّةٌ
# أسئِلَتِها
# أَسَاسِيَّةٍ
# أسْبُوعَ
# أَسَدٍ
# أظفَرُ
# أظْهَرَتْ
# أَظْهَرَتْ
# أَعْدَدْتُ
# أَعْرَبَ
# أعْلَنَتْ
# أعْلَى
# أَفْنَى
# أُقابِلَ
# أكْثَرَ
# أَكَّدَتْ
# أكونُ
# أَمِيرِ
# أن
# أنَّ
# أنْ
# أَنَّ
# أنا
# أَنْحَاءَ
# أَوْ
# أُورُوبَّا
# أَوَّلاً
# إطْلَاقَ
# إِقْلِيمِ
# إلَى
# إِمْكَانِيَّتِهَا
# إنْ
# إِنَّ
# إنّها
# ابْتِدَاءً
# ابْنَةِ
# اثْنَا
# اسْتِخْدَامَ
# اسْتِعْمَالُ
# اسْتُعْمِلَتْ
# اِسْتَقْبَلَتْني
# اسْتَمَرَّ
# اسْمَ
# اِسْمٌ
# اصْطَدَمَ
# الْـSIXNINE
# الْأجْهِزَةِ
# الْأدَوَاتِ
# الْأَرْبِعَاءَ
# الأرض
# الْأرْضِ
# الأستاذُ
# الْأَطْعِمَةِ
# الْأطْفَالُ
# الْأَقَلِّيَاتِ
# الْأَمِيرِ
# الْأميرِكِيِّ
# الْأَمِيرْكِيَّةِ
# الإجابَةِ
# الْإرْهَابِ
# الْإِسْرَائِيلِيِّ
# الْإِسْلَامِيَّ
# الْإِلِكْتِرُونِيَّةُ
# الْإنْتَرْنِت
# الْإنْسَانِ
# الانْتِحَارِ
# الْبَدَنِيُّ
# ...

# %%
test = ["a", "b"]
test.remove("a")
test
# Out:
# ['b']

# %%
for i in diction_fulltext:
    if("الْقَصِيرَةِ" in i):
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2faa4aa98ca1> in <module>
# ----> 1 for i in diction_fulltext:
#       2     if("الْقَصِيرَةِ" in i):
#       3         print(i)
#
# NameError: name 'diction_fulltext' is not defined

# %%
"الْقَصِيرَةِ" in "الْقَصِيرَةِ		A l q a S i y r a t i  sp "
# Out:
# True

# %%
"abcd".find("d")
# Out:
# 3
